# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.
#
# Please make sure if you are running this notebook in the workspace that you have chosen GPU rather than CPU mode.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import numpy as np
import json

import torch
from torch import nn
from torch import optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
from torchvision import datasets, transforms, models

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                     transforms.RandomCrop(224),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224, 0.225])])



# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
valid_data = datasets.ImageFolder(valid_dir, transform=test_transforms)
test_data = datasets.ImageFolder(test_dir, transform=test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=64)                               
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %%
# set image datasets
image_datasets = {'train':train_data,'valid':valid_data,'test':test_data}
#print(image_datasets['train'].class_to_idx)

# %%
# show image
def imshow(image, ax=None, title=None, normalize=True):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

# %%
# check shape and see a picture
images, labels = next(iter(trainloader))
imshow(images[0], normalize=True)
len(iter(trainloader))
# Out:
# 103

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

#print(cat_to_name)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.

# %%
# TODO: Build and train your network

# Build network
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load pretrained network
model = models.vgg16(pretrained=True)
print(model)

# Freeze parameters
for param in model.parameters():
    param.requires_grad = False
    
# Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# note that there are 102 catorigories
model.classifier = nn.Sequential(nn.Linear(25088, 4096),
                                 nn.ReLU(),
                                 nn.Dropout(0.5),
                                 nn.Linear(4096,4096),
                                 nn.ReLU(),
                                 nn.Dropout(0.3),
                                 nn.Linear(4096, 102),
                                 nn.LogSoftmax(dim=1))

criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
# shrink learning rate every 5 epochs
#scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

model.to(device);
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# train network
# maybe need to change this
epochs = 12
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
    for inputs, labels in trainloader:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        
        # empty grads
        optimizer.zero_grad()
        
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        if steps % print_every == 0:
            valid_loss = 0
            accuracy = 0
            # turn on eval mode when evaluate the model
            model.eval()
            with torch.no_grad():
                for inputs, labels in validloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    valid_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {valid_loss/len(validloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(validloader):.3f}")
            running_loss = 0
            #scheduler.step()
            model.train()
# Out:
# Epoch 1/12.. Train loss: 6.354.. Test loss: 4.701.. Test accuracy: 0.019
# Epoch 1/12.. Train loss: 4.583.. Test loss: 4.477.. Test accuracy: 0.049
# Epoch 1/12.. Train loss: 4.349.. Test loss: 4.486.. Test accuracy: 0.061
# Epoch 1/12.. Train loss: 4.292.. Test loss: 4.215.. Test accuracy: 0.109
# Epoch 1/12.. Train loss: 4.063.. Test loss: 3.944.. Test accuracy: 0.188
# Epoch 1/12.. Train loss: 3.957.. Test loss: 3.681.. Test accuracy: 0.201
# Epoch 1/12.. Train loss: 3.726.. Test loss: 3.348.. Test accuracy: 0.237
# Epoch 1/12.. Train loss: 3.467.. Test loss: 3.209.. Test accuracy: 0.245
# Epoch 1/12.. Train loss: 3.474.. Test loss: 3.073.. Test accuracy: 0.248
# Epoch 1/12.. Train loss: 3.426.. Test loss: 3.045.. Test accuracy: 0.260
# Epoch 1/12.. Train loss: 3.065.. Test loss: 2.861.. Test accuracy: 0.304
# Epoch 1/12.. Train loss: 3.184.. Test loss: 3.063.. Test accuracy: 0.271
# Epoch 1/12.. Train loss: 3.058.. Test loss: 2.710.. Test accuracy: 0.334
# Epoch 1/12.. Train loss: 3.025.. Test loss: 2.500.. Test accuracy: 0.350
# Epoch 1/12.. Train loss: 2.969.. Test loss: 2.472.. Test accuracy: 0.360
# Epoch 1/12.. Train loss: 2.910.. Test loss: 2.602.. Test accuracy: 0.326
# Epoch 1/12.. Train loss: 2.815.. Test loss: 2.594.. Test accuracy: 0.339
# Epoch 1/12.. Train loss: 2.787.. Test loss: 2.452.. Test accuracy: 0.346
# Epoch 1/12.. Train loss: 2.958.. Test loss: 2.459.. Test accuracy: 0.343
# Epoch 1/12.. Train loss: 2.700.. Test loss: 2.326.. Test accuracy: 0.409
# Epoch 2/12.. Train loss: 2.842.. Test loss: 2.381.. Test accuracy: 0.387
# Epoch 2/12.. Train loss: 2.917.. Test loss: 2.482.. Test accuracy: 0.338
# Epoch 2/12.. Train loss: 2.794.. Test loss: 2.351.. Test accuracy: 0.384
# Epoch 2/12.. Train loss: 2.537.. Test loss: 2.273.. Test accuracy: 0.427
# Epoch 2/12.. Train loss: 2.715.. Test loss: 2.141.. Test accuracy: 0.448
# Epoch 2/12.. Train loss: 2.630.. Test loss: 2.102.. Test accuracy: 0.435
# Epoch 2/12.. Train loss: 2.658.. Test loss: 2.196.. Test accuracy: 0.417
# Epoch 2/12.. Train loss: 2.591.. Test loss: 2.352.. Test accuracy: 0.400
# Epoch 2/12.. Train loss: 2.909.. Test loss: 2.756.. Test accuracy: 0.329
# Epoch 2/12.. Train loss: 2.725.. Test loss: 2.254.. Test accuracy: 0.408
# Epoch 2/12.. Train loss: 2.804.. Test loss: 2.257.. Test accuracy: 0.397
# Epoch 2/12.. Train loss: 2.697.. Test loss: 2.062.. Test accuracy: 0.448
# Epoch 2/12.. Train loss: 2.772.. Test loss: 2.106.. Test accuracy: 0.448
# Epoch 2/12.. Train loss: 2.873.. Test loss: 2.097.. Test accuracy: 0.427
# Epoch 2/12.. Train loss: 2.649.. Test loss: 2.059.. Test accuracy: 0.446
# Epoch 2/12.. Train loss: 2.434.. Test loss: 2.096.. Test accuracy: 0.432
# Epoch 2/12.. Train loss: 2.548.. Test loss: 2.343.. Test accuracy: 0.398
# Epoch 2/12.. Train loss: 2.621.. Test loss: 2.241.. Test accuracy: 0.425
# Epoch 2/12.. Train loss: 2.542.. Test loss: 1.935.. Test accuracy: 0.491
# Epoch 2/12.. Train loss: 2.670.. Test loss: 2.110.. Test accuracy: 0.432
# Epoch 2/12.. Train loss: 2.680.. Test loss: 2.101.. Test accuracy: 0.441
# Epoch 3/12.. Train loss: 2.482.. Test loss: 2.037.. Test accuracy: 0.455
# Epoch 3/12.. Train loss: 2.295.. Test loss: 2.003.. Test accuracy: 0.468
# Epoch 3/12.. Train loss: 2.379.. Test loss: 2.076.. Test accuracy: 0.460
# Epoch 3/12.. Train loss: 2.524.. Test loss: 2.312.. Test accuracy: 0.422
# Epoch 3/12.. Train loss: 2.554.. Test loss: 2.247.. Test accuracy: 0.420
# Epoch 3/12.. Train loss: 2.625.. Test loss: 2.322.. Test accuracy: 0.419
# Epoch 3/12.. Train loss: 2.300.. Test loss: 2.040.. Test accuracy: 0.473
# Epoch 3/12.. Train loss: 2.368.. Test loss: 2.011.. Test accuracy: 0.464
# Epoch 3/12.. Train loss: 2.765.. Test loss: 2.190.. Test accuracy: 0.441
# Epoch 3/12.. Train loss: 2.648.. Test loss: 2.151.. Test accuracy: 0.454
# Epoch 3/12.. Train loss: 2.581.. Test loss: 2.081.. Test accuracy: 0.478
# Epoch 3/12.. Train loss: 2.500.. Test loss: 1.951.. Test accuracy: 0.483
# Epoch 3/12.. Train loss: 2.270.. Test loss: 1.860.. Test accuracy: 0.502
# Epoch 3/12.. Train loss: 2.303.. Test loss: 1.990.. Test accuracy: 0.476
# Epoch 3/12.. Train loss: 2.421.. Test loss: 2.141.. Test accuracy: 0.480
# Epoch 3/12.. Train loss: 2.450.. Test loss: 2.072.. Test accuracy: 0.478
# Epoch 3/12.. Train loss: 2.349.. Test loss: 1.960.. Test accuracy: 0.490
# Epoch 3/12.. Train loss: 2.356.. Test loss: 1.971.. Test accuracy: 0.494
# Epoch 3/12.. Train loss: 2.400.. Test loss: 1.871.. Test accuracy: 0.509
# Epoch 3/12.. Train loss: 2.383.. Test loss: 1.920.. Test accuracy: 0.488
# Epoch 4/12.. Train loss: 2.495.. Test loss: 1.853.. Test accuracy: 0.522
# Epoch 4/12.. Train loss: 2.594.. Test loss: 1.994.. Test accuracy: 0.470
# Epoch 4/12.. Train loss: 2.380.. Test loss: 1.969.. Test accuracy: 0.500
# Epoch 4/12.. Train loss: 2.387.. Test loss: 1.885.. Test accuracy: 0.517
# Epoch 4/12.. Train loss: 2.298.. Test loss: 1.894.. Test accuracy: 0.497
# Epoch 4/12.. Train loss: 2.323.. Test loss: 1.924.. Test accuracy: 0.484
# Epoch 4/12.. Train loss: 2.131.. Test loss: 1.881.. Test accuracy: 0.496
# Epoch 4/12.. Train loss: 2.348.. Test loss: 2.003.. Test accuracy: 0.474
# Epoch 4/12.. Train loss: 2.459.. Test loss: 1.791.. Test accuracy: 0.529
# Epoch 4/12.. Train loss: 2.446.. Test loss: 1.776.. Test accuracy: 0.554
# Epoch 4/12.. Train loss: 2.294.. Test loss: 1.811.. Test accuracy: 0.530
# Epoch 4/12.. Train loss: 2.323.. Test loss: 1.885.. Test accuracy: 0.509
# Epoch 4/12.. Train loss: 2.307.. Test loss: 2.062.. Test accuracy: 0.477
# Epoch 4/12.. Train loss: 2.380.. Test loss: 1.883.. Test accuracy: 0.487
# Epoch 4/12.. Train loss: 2.387.. Test loss: 1.788.. Test accuracy: 0.517
# Epoch 4/12.. Train loss: 2.404.. Test loss: 1.826.. Test accuracy: 0.530
# Epoch 4/12.. Train loss: 2.426.. Test loss: 2.005.. Test accuracy: 0.493
# Epoch 4/12.. Train loss: 2.433.. Test loss: 2.028.. Test accuracy: 0.487
# Epoch 4/12.. Train loss: 2.278.. Test loss: 1.956.. Test accuracy: 0.476
# Epoch 4/12.. Train loss: 2.054.. Test loss: 1.815.. Test accuracy: 0.527
# Epoch 4/12.. Train loss: 2.239.. Test loss: 1.762.. Test accuracy: 0.534
# Epoch 5/12.. Train loss: 2.505.. Test loss: 1.927.. Test accuracy: 0.515
# Epoch 5/12.. Train loss: 2.105.. Test loss: 1.952.. Test accuracy: 0.506
# Epoch 5/12.. Train loss: 2.424.. Test loss: 1.851.. Test accuracy: 0.519
# Epoch 5/12.. Train loss: 2.316.. Test loss: 1.768.. Test accuracy: 0.558
# Epoch 5/12.. Train loss: 2.177.. Test loss: 1.838.. Test accuracy: 0.548
# Epoch 5/12.. Train loss: 2.261.. Test loss: 1.847.. Test accuracy: 0.527
# Epoch 5/12.. Train loss: 2.138.. Test loss: 1.725.. Test accuracy: 0.554
# Epoch 5/12.. Train loss: 2.242.. Test loss: 1.776.. Test accuracy: 0.541
# Epoch 5/12.. Train loss: 2.178.. Test loss: 1.711.. Test accuracy: 0.552
# Epoch 5/12.. Train loss: 2.319.. Test loss: 1.660.. Test accuracy: 0.548
# Epoch 5/12.. Train loss: 2.286.. Test loss: 1.679.. Test accuracy: 0.562
# Epoch 5/12.. Train loss: 2.263.. Test loss: 1.672.. Test accuracy: 0.576
# Epoch 5/12.. Train loss: 2.179.. Test loss: 1.699.. Test accuracy: 0.565
# Epoch 5/12.. Train loss: 2.209.. Test loss: 1.713.. Test accuracy: 0.553
# Epoch 5/12.. Train loss: 2.057.. Test loss: 1.654.. Test accuracy: 0.575
# Epoch 5/12.. Train loss: 2.349.. Test loss: 1.656.. Test accuracy: 0.578
# Epoch 5/12.. Train loss: 2.192.. Test loss: 1.728.. Test accuracy: 0.539
# Epoch 5/12.. Train loss: 2.495.. Test loss: 1.761.. Test accuracy: 0.537
# Epoch 5/12.. Train loss: 2.283.. Test loss: 1.745.. Test accuracy: 0.549
# Epoch 5/12.. Train loss: 2.205.. Test loss: 1.766.. Test accuracy: 0.542
# Epoch 5/12.. Train loss: 2.310.. Test loss: 1.750.. Test accuracy: 0.525
# Epoch 6/12.. Train loss: 2.198.. Test loss: 1.682.. Test accuracy: 0.559
# Epoch 6/12.. Train loss: 2.307.. Test loss: 1.729.. Test accuracy: 0.555
# Epoch 6/12.. Train loss: 2.311.. Test loss: 1.720.. Test accuracy: 0.570
# Epoch 6/12.. Train loss: 2.190.. Test loss: 1.777.. Test accuracy: 0.560
# Epoch 6/12.. Train loss: 2.200.. Test loss: 1.795.. Test accuracy: 0.562
# Epoch 6/12.. Train loss: 2.137.. Test loss: 1.812.. Test accuracy: 0.550
# Epoch 6/12.. Train loss: 1.991.. Test loss: 1.913.. Test accuracy: 0.497
# Epoch 6/12.. Train loss: 2.133.. Test loss: 1.801.. Test accuracy: 0.524
# Epoch 6/12.. Train loss: 2.189.. Test loss: 1.643.. Test accuracy: 0.582
# Epoch 6/12.. Train loss: 2.135.. Test loss: 1.580.. Test accuracy: 0.600
# Epoch 6/12.. Train loss: 2.320.. Test loss: 1.632.. Test accuracy: 0.597
# Epoch 6/12.. Train loss: 2.052.. Test loss: 1.738.. Test accuracy: 0.566
# Epoch 6/12.. Train loss: 2.255.. Test loss: 1.727.. Test accuracy: 0.568
# Epoch 6/12.. Train loss: 2.206.. Test loss: 1.682.. Test accuracy: 0.589
# Epoch 6/12.. Train loss: 2.208.. Test loss: 1.679.. Test accuracy: 0.586
# Epoch 6/12.. Train loss: 2.258.. Test loss: 1.798.. Test accuracy: 0.544
# Epoch 6/12.. Train loss: 2.261.. Test loss: 1.914.. Test accuracy: 0.532
# Epoch 6/12.. Train loss: 2.167.. Test loss: 1.987.. Test accuracy: 0.530
# Epoch 6/12.. Train loss: 2.239.. Test loss: 1.948.. Test accuracy: 0.560
# Epoch 6/12.. Train loss: 2.208.. Test loss: 1.753.. Test accuracy: 0.568
# Epoch 7/12.. Train loss: 2.022.. Test loss: 1.743.. Test accuracy: 0.553
# Epoch 7/12.. Train loss: 2.088.. Test loss: 1.803.. Test accuracy: 0.538
# Epoch 7/12.. Train loss: 2.140.. Test loss: 1.704.. Test accuracy: 0.570
# Epoch 7/12.. Train loss: 2.312.. Test loss: 1.704.. Test accuracy: 0.571
# Epoch 7/12.. Train loss: 2.156.. Test loss: 1.717.. Test accuracy: 0.551
# Epoch 7/12.. Train loss: 2.151.. Test loss: 1.688.. Test accuracy: 0.554
# Epoch 7/12.. Train loss: 2.373.. Test loss: 1.737.. Test accuracy: 0.542
# Epoch 7/12.. Train loss: 2.280.. Test loss: 1.749.. Test accuracy: 0.560
# Epoch 7/12.. Train loss: 2.305.. Test loss: 1.763.. Test accuracy: 0.564
# Epoch 7/12.. Train loss: 2.153.. Test loss: 1.688.. Test accuracy: 0.574
# Epoch 7/12.. Train loss: 2.148.. Test loss: 1.692.. Test accuracy: 0.581
# Epoch 7/12.. Train loss: 2.214.. Test loss: 1.618.. Test accuracy: 0.591
# Epoch 7/12.. Train loss: 2.307.. Test loss: 1.655.. Test accuracy: 0.577
# Epoch 7/12.. Train loss: 2.212.. Test loss: 1.775.. Test accuracy: 0.546
# Epoch 7/12.. Train loss: 2.384.. Test loss: 1.752.. Test accuracy: 0.557
# Epoch 7/12.. Train loss: 2.251.. Test loss: 1.743.. Test accuracy: 0.567
# Epoch 7/12.. Train loss: 2.192.. Test loss: 1.682.. Test accuracy: 0.582
# Epoch 7/12.. Train loss: 2.272.. Test loss: 1.609.. Test accuracy: 0.590
# Epoch 7/12.. Train loss: 2.318.. Test loss: 1.600.. Test accuracy: 0.591
# Epoch 7/12.. Train loss: 1.993.. Test loss: 1.650.. Test accuracy: 0.595
# Epoch 7/12.. Train loss: 2.018.. Test loss: 1.683.. Test accuracy: 0.573
# Epoch 8/12.. Train loss: 2.243.. Test loss: 1.724.. Test accuracy: 0.579
# Epoch 8/12.. Train loss: 2.109.. Test loss: 1.993.. Test accuracy: 0.528
# Epoch 8/12.. Train loss: 2.076.. Test loss: 1.920.. Test accuracy: 0.534
# Epoch 8/12.. Train loss: 2.300.. Test loss: 1.878.. Test accuracy: 0.548
# Epoch 8/12.. Train loss: 2.041.. Test loss: 1.865.. Test accuracy: 0.543
# Epoch 8/12.. Train loss: 2.113.. Test loss: 1.730.. Test accuracy: 0.568
# Epoch 8/12.. Train loss: 2.283.. Test loss: 1.655.. Test accuracy: 0.581
# Epoch 8/12.. Train loss: 2.228.. Test loss: 1.752.. Test accuracy: 0.557
# Epoch 8/12.. Train loss: 2.379.. Test loss: 1.700.. Test accuracy: 0.592
# Epoch 8/12.. Train loss: 2.207.. Test loss: 1.741.. Test accuracy: 0.589
# Epoch 8/12.. Train loss: 1.993.. Test loss: 1.675.. Test accuracy: 0.587
# Epoch 8/12.. Train loss: 2.106.. Test loss: 1.624.. Test accuracy: 0.582
# Epoch 8/12.. Train loss: 2.109.. Test loss: 1.714.. Test accuracy: 0.571
# Epoch 8/12.. Train loss: 2.084.. Test loss: 1.758.. Test accuracy: 0.565
# Epoch 8/12.. Train loss: 2.175.. Test loss: 1.755.. Test accuracy: 0.552
# Epoch 8/12.. Train loss: 2.225.. Test loss: 1.752.. Test accuracy: 0.546
# Epoch 8/12.. Train loss: 2.094.. Test loss: 1.736.. Test accuracy: 0.558
# Epoch 8/12.. Train loss: 2.221.. Test loss: 1.636.. Test accuracy: 0.573
# Epoch 8/12.. Train loss: 2.191.. Test loss: 1.660.. Test accuracy: 0.570
# Epoch 8/12.. Train loss: 2.108.. Test loss: 1.723.. Test accuracy: 0.548
# Epoch 9/12.. Train loss: 1.997.. Test loss: 1.697.. Test accuracy: 0.557
# Epoch 9/12.. Train loss: 2.151.. Test loss: 1.711.. Test accuracy: 0.575
# Epoch 9/12.. Train loss: 2.279.. Test loss: 1.716.. Test accuracy: 0.574
# Epoch 9/12.. Train loss: 2.047.. Test loss: 1.680.. Test accuracy: 0.579
# Epoch 9/12.. Train loss: 2.003.. Test loss: 1.627.. Test accuracy: 0.576
# Epoch 9/12.. Train loss: 2.064.. Test loss: 1.662.. Test accuracy: 0.561
# Epoch 9/12.. Train loss: 2.327.. Test loss: 1.628.. Test accuracy: 0.580
# Epoch 9/12.. Train loss: 2.126.. Test loss: 1.583.. Test accuracy: 0.598
# Epoch 9/12.. Train loss: 2.234.. Test loss: 1.631.. Test accuracy: 0.583
# Epoch 9/12.. Train loss: 2.055.. Test loss: 1.672.. Test accuracy: 0.573
# Epoch 9/12.. Train loss: 2.439.. Test loss: 1.639.. Test accuracy: 0.591
# Epoch 9/12.. Train loss: 2.050.. Test loss: 1.684.. Test accuracy: 0.571
# Epoch 9/12.. Train loss: 2.299.. Test loss: 1.676.. Test accuracy: 0.583
# Epoch 9/12.. Train loss: 2.073.. Test loss: 1.650.. Test accuracy: 0.590
# Epoch 9/12.. Train loss: 2.241.. Test loss: 1.624.. Test accuracy: 0.583
# Epoch 9/12.. Train loss: 2.051.. Test loss: 1.619.. Test accuracy: 0.600
# Epoch 9/12.. Train loss: 2.107.. Test loss: 1.555.. Test accuracy: 0.613
# Epoch 9/12.. Train loss: 2.198.. Test loss: 1.552.. Test accuracy: 0.634
# Epoch 9/12.. Train loss: 2.048.. Test loss: 1.599.. Test accuracy: 0.616
# Epoch 9/12.. Train loss: 2.039.. Test loss: 1.591.. Test accuracy: 0.609
# Epoch 9/12.. Train loss: 1.913.. Test loss: 1.595.. Test accuracy: 0.602
# Epoch 10/12.. Train loss: 2.171.. Test loss: 1.574.. Test accuracy: 0.590
# Epoch 10/12.. Train loss: 2.074.. Test loss: 1.586.. Test accuracy: 0.590
# Epoch 10/12.. Train loss: 2.224.. Test loss: 1.683.. Test accuracy: 0.578
# Epoch 10/12.. Train loss: 2.212.. Test loss: 1.692.. Test accuracy: 0.596
# Epoch 10/12.. Train loss: 2.172.. Test loss: 1.652.. Test accuracy: 0.600
# Epoch 10/12.. Train loss: 1.946.. Test loss: 1.634.. Test accuracy: 0.586
# Epoch 10/12.. Train loss: 1.907.. Test loss: 1.622.. Test accuracy: 0.579
# Epoch 10/12.. Train loss: 2.048.. Test loss: 1.632.. Test accuracy: 0.599
# Epoch 10/12.. Train loss: 1.992.. Test loss: 1.627.. Test accuracy: 0.589
# Epoch 10/12.. Train loss: 1.811.. Test loss: 1.714.. Test accuracy: 0.576
# Epoch 10/12.. Train loss: 2.339.. Test loss: 1.758.. Test accuracy: 0.569
# Epoch 10/12.. Train loss: 2.429.. Test loss: 1.850.. Test accuracy: 0.556
# Epoch 10/12.. Train loss: 2.073.. Test loss: 1.805.. Test accuracy: 0.584
# Epoch 10/12.. Train loss: 2.305.. Test loss: 1.767.. Test accuracy: 0.585
# Epoch 10/12.. Train loss: 1.961.. Test loss: 1.714.. Test accuracy: 0.577
# Epoch 10/12.. Train loss: 2.274.. Test loss: 1.657.. Test accuracy: 0.598
# Epoch 10/12.. Train loss: 2.078.. Test loss: 1.577.. Test accuracy: 0.624
# Epoch 10/12.. Train loss: 2.047.. Test loss: 1.517.. Test accuracy: 0.630
# Epoch 10/12.. Train loss: 1.920.. Test loss: 1.552.. Test accuracy: 0.612
# Epoch 10/12.. Train loss: 2.389.. Test loss: 1.587.. Test accuracy: 0.618
# Epoch 10/12.. Train loss: 2.386.. Test loss: 1.648.. Test accuracy: 0.584
# Epoch 11/12.. Train loss: 2.126.. Test loss: 1.757.. Test accuracy: 0.581
# Epoch 11/12.. Train loss: 2.139.. Test loss: 1.744.. Test accuracy: 0.585
# Epoch 11/12.. Train loss: 2.374.. Test loss: 1.728.. Test accuracy: 0.589
# Epoch 11/12.. Train loss: 1.911.. Test loss: 1.705.. Test accuracy: 0.598
# Epoch 11/12.. Train loss: 2.062.. Test loss: 1.544.. Test accuracy: 0.609
# Epoch 11/12.. Train loss: 2.249.. Test loss: 1.520.. Test accuracy: 0.625
# Epoch 11/12.. Train loss: 2.184.. Test loss: 1.532.. Test accuracy: 0.612
# Epoch 11/12.. Train loss: 1.952.. Test loss: 1.563.. Test accuracy: 0.611
# Epoch 11/12.. Train loss: 2.050.. Test loss: 1.615.. Test accuracy: 0.611
# Epoch 11/12.. Train loss: 2.163.. Test loss: 1.584.. Test accuracy: 0.604
# Epoch 11/12.. Train loss: 1.936.. Test loss: 1.603.. Test accuracy: 0.610
# Epoch 11/12.. Train loss: 2.213.. Test loss: 1.660.. Test accuracy: 0.582
# Epoch 11/12.. Train loss: 2.074.. Test loss: 1.693.. Test accuracy: 0.594
# Epoch 11/12.. Train loss: 1.999.. Test loss: 1.623.. Test accuracy: 0.604
# Epoch 11/12.. Train loss: 2.068.. Test loss: 1.575.. Test accuracy: 0.607
# Epoch 11/12.. Train loss: 2.018.. Test loss: 1.579.. Test accuracy: 0.618
# Epoch 11/12.. Train loss: 2.049.. Test loss: 1.728.. Test accuracy: 0.581
# Epoch 11/12.. Train loss: 1.795.. Test loss: 1.799.. Test accuracy: 0.553
# Epoch 11/12.. Train loss: 2.065.. Test loss: 1.619.. Test accuracy: 0.600
# Epoch 12/12.. Train loss: 1.796.. Test loss: 1.568.. Test accuracy: 0.619
# Epoch 12/12.. Train loss: 2.030.. Test loss: 1.568.. Test accuracy: 0.595
# Epoch 12/12.. Train loss: 2.056.. Test loss: 1.515.. Test accuracy: 0.620
# Epoch 12/12.. Train loss: 1.913.. Test loss: 1.522.. Test accuracy: 0.602
# Epoch 12/12.. Train loss: 1.827.. Test loss: 1.546.. Test accuracy: 0.607
# Epoch 12/12.. Train loss: 2.199.. Test loss: 1.631.. Test accuracy: 0.608
# Epoch 12/12.. Train loss: 2.112.. Test loss: 1.707.. Test accuracy: 0.586
# Epoch 12/12.. Train loss: 2.143.. Test loss: 1.635.. Test accuracy: 0.602
# Epoch 12/12.. Train loss: 2.101.. Test loss: 1.606.. Test accuracy: 0.605
# Epoch 12/12.. Train loss: 2.050.. Test loss: 1.635.. Test accuracy: 0.601
# Epoch 12/12.. Train loss: 2.064.. Test loss: 1.650.. Test accuracy: 0.590
# Epoch 12/12.. Train loss: 1.951.. Test loss: 1.697.. Test accuracy: 0.586
# Epoch 12/12.. Train loss: 1.986.. Test loss: 1.697.. Test accuracy: 0.597
# Epoch 12/12.. Train loss: 2.007.. Test loss: 1.621.. Test accuracy: 0.609
# Epoch 12/12.. Train loss: 2.130.. Test loss: 1.605.. Test accuracy: 0.595
# Epoch 12/12.. Train loss: 2.051.. Test loss: 1.584.. Test accuracy: 0.597
# Epoch 12/12.. Train loss: 1.978.. Test loss: 1.621.. Test accuracy: 0.601
# Epoch 12/12.. Train loss: 2.165.. Test loss: 1.640.. Test accuracy: 0.611

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
test_loss = 0
accuracy = 0
# turn on eval mode when evaluate the model
model.eval()
with torch.no_grad():
    for inputs, labels in testloader:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)
                    
        test_loss += batch_loss.item()
                    
        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
        print(f"Test loss: {test_loss/len(testloader):.3f}.. "
              f"Test accuracy: {accuracy/len(testloader):.3f}")
# Out:
# Test loss: 0.135.. Test accuracy: 0.042
# Test loss: 0.257.. Test accuracy: 0.093
# Test loss: 0.421.. Test accuracy: 0.132
# Test loss: 0.660.. Test accuracy: 0.156
# Test loss: 0.740.. Test accuracy: 0.213
# Test loss: 0.875.. Test accuracy: 0.256
# Test loss: 0.940.. Test accuracy: 0.316
# Test loss: 1.109.. Test accuracy: 0.352
# Test loss: 1.175.. Test accuracy: 0.412
# Test loss: 1.259.. Test accuracy: 0.469
# Test loss: 1.424.. Test accuracy: 0.506
# Test loss: 1.560.. Test accuracy: 0.553
# Test loss: 1.689.. Test accuracy: 0.600

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
#model.class_to_idx = train_datasets['train'].class_to_idx
model.class_to_idx = image_datasets['train'].class_to_idx
checkpoint = {'model_state': model.state_dict(),
              'class_to_idx': model.class_to_idx ,
              'criterion_state': criterion.state_dict(),
              'optimizer_state': optimizer.state_dict(),
              'epochs': epochs}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath,map_location=lambda storage, loc: storage)
    # load model
    model = models.vgg16()
    model.classifier = nn.Sequential(nn.Linear(25088, 4096),
                                 nn.ReLU(),
                                 nn.Dropout(0.5),
                                 nn.Linear(4096,4096),
                                 nn.ReLU(),
                                 nn.Dropout(0.3),
                                 nn.Linear(4096, 102),
                                 nn.LogSoftmax(dim=1))

    model.load_state_dict(checkpoint['model_state'])
    model.class_to_idx = checkpoint['class_to_idx']
    # load criterion
    criterion = nn.NLLLoss()
    criterion.load_state_dict(checkpoint['criterion_state'])
    # load optimizer
    optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
    optimizer.load_state_dict(checkpoint['optimizer_state'])
    return model,criterion,optimizer

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model,criterion,optimizer = load_checkpoint('checkpoint.pth')

#model.eval()
print(model)
# Out:
# cuda
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3)
#     (6): Linear(in_features=4096, out_features=102, bias=True)
#     (7): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    # reference to this blog :https://medium.com/@josh_2774/deep-learning-with-pytorch-9574e74d17ad
    # resize
    if image.size[0] > image.size[1]:
        image.thumbnail((10000, 256))
    else:
        image.thumbnail((256, 10000))
    # crop
    width, height = image.size
    left = (width - 224)/2
    top = (height - 224)/2
    right = (width + 224)/2
    bottom = (height + 224)/2
    image = image.crop((left, top, right, bottom))
    # normolize
    np_image = np.array(image)/255
    mean = np.array([0.485, 0.456, 0.406]) 
    std = np.array([0.229, 0.224, 0.225]) 
    np_image = (np_image - mean)/std
    np_image = np_image.transpose((2, 0, 1))
    
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # TODO: Implement the code to predict the class from an image file
    # reference to this blog :https://medium.com/@josh_2774/deep-learning-with-pytorch-9574e74d17ad
    # prepare image
    image = Image.open(image_path)
    image_np = process_image(image)
    # numpy to tensor
    image_tensor = torch.from_numpy(image_np).type(torch.FloatTensor)
    image_tensor = image_tensor.unsqueeze(0)
    # get ps for each class
    logps = model.forward(image_tensor)
    ps = torch.exp(logps)
    # get top five class
    top_probs, top_labs = ps.topk(5, dim=1)
    # tensor to list
    top_probs = top_probs.detach().numpy().tolist()[0] 
    top_labs = top_labs.detach().numpy().tolist()[0]
    # indices to classes
    idx_to_class = {val: key for key, val in model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labs]
    top_flowers = [cat_to_name[idx_to_class[lab]] for lab in top_labs]
    return top_probs, top_labs,top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
def plot_result(image_path, model):
    # Set up plot
    plt.figure(figsize = (6,10))
    ax1 = plt.subplot(2,1,1)
    # Set up title
    flower_num = image_path.split('/')[2]
    title_ = cat_to_name[flower_num]
    # Plot flower
    image = Image.open(image_path)
    img = process_image(image)
    imshow(img, ax1, title = title_);
    ax1.set_title(title_)
    # Make prediction
    probs, labs, flowers = predict(image_path, model) 
    # Plot bar chart
    plt.subplot(2,1,2)
    ax = plt.barh(flowers, probs)
    plt.show()

# %%
image_path = train_dir  + '/1/image_06742.jpg'
plot_result(image_path,model)
